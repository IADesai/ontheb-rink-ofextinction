# %%
import pandas as pd
from datetime import datetime as dt

# %%
df = pd.read_csv('practice.csv')
df = df.head(5)
df
# Out:
#    Unnamed: 0    Botanist_Name              Botanist_Email  \
# 0           0  Gertrude Jekyll  gertrude.jekyll@lnhm.co.uk
# 1           1    Carl Linnaeus    carl.linnaeus@lnhm.co.uk
# 2           2    Eliza Andrews    eliza.andrews@lnhm.co.uk
# 3           3    Carl Linnaeus    carl.linnaeus@lnhm.co.uk
# 4           4    Carl Linnaeus    carl.linnaeus@lnhm.co.uk
#
#          Botanist_Phone         Last_Watered          Plant_Name  \
# 0  001-481-273-3691x127  2023-08-30 13:54:32       Venus flytrap
# 1   (146)994-1635x35992  2023-08-30 14:10:54       Corpse flower
# 2   (846)669-6651x75948  2023-08-30 14:50:16  Rafflesia arnoldii
# 3   (146)994-1635x35992  2023-08-30 13:16:25    Black bat flower
# 4   (146)994-1635x35992  2023-08-29 14:56:18       Pitcher plant
#
#         Scientific_Name       Recording_Time                 Cycle  \
# 0                   NaN  2023-08-30 14:56:09                   NaN
# 1                   NaN  2023-08-30 14:56:10                   NaN
# ...

# %%
data = dt.strptime('Wed, 30 Feb 2023 13:54:32 GMT', '%a, %d %b %Y %H:%M:%S %Z')
date
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 data = dt.strptime('Wed, 30 Feb 2023 13:54:32 GMT', '%a, %d %b %Y %H:%M:%S %Z')
#       2 date
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/_strptime.py:534, in _strptime(data_string, format)
#     527         julian += yday
# ...

# %%
def check_temperature_within_correct_ranges(temperature: float) -> float| str:
    if temperature < 3:
        return 'Invalid'
    elif temperature > 45:
        return 'Invalid'
    else:
        return temperature

# %%
df['Temperature'] = df['Temperature'].apply(
        lambda x: check_temperature_within_correct_ranges(x))
df
# Out:
#    Unnamed: 0    Botanist_Name              Botanist_Email  \
# 0           0  Gertrude Jekyll  gertrude.jekyll@lnhm.co.uk
# 1           1    Carl Linnaeus    carl.linnaeus@lnhm.co.uk
# 2           2    Eliza Andrews    eliza.andrews@lnhm.co.uk
# 3           3    Carl Linnaeus    carl.linnaeus@lnhm.co.uk
# 4           4    Carl Linnaeus    carl.linnaeus@lnhm.co.uk
#
#          Botanist_Phone         Last_Watered          Plant_Name  \
# 0  001-481-273-3691x127  2023-08-30 13:54:32       Venus flytrap
# 1   (146)994-1635x35992  2023-08-30 14:10:54       Corpse flower
# 2   (846)669-6651x75948  2023-08-30 14:50:16  Rafflesia arnoldii
# 3   (146)994-1635x35992  2023-08-30 13:16:25    Black bat flower
# 4   (146)994-1635x35992  2023-08-29 14:56:18       Pitcher plant
#
#         Scientific_Name       Recording_Time                 Cycle  \
# 0                   NaN  2023-08-30 14:56:09                   NaN
# 1                   NaN  2023-08-30 14:56:10                   NaN
# ...
